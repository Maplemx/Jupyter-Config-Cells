# %% [markdown]
# ### Test1: YAML Config

# %%
# to: test_settings
test_dict:
    test_key_1: testing
    test_key_2: 123
    test_key_3:
        - abc
        - 456
test_list:
    - 13
    - 13
    - ltt
    - 677
    - ok: true
      msg: It works.

# %%
# Generated by Jupyter Config Cells. Edit the config cell above instead.
import json as _json

_config_source = r"""
test_dict:
    test_key_1: testing
    test_key_2: 123
    test_key_3:
        - abc
        - 456
test_list:
    - 13
    - 13
    - ltt
    - 677
    - ok: true
      msg: It works.

""".strip("\n")

test_settings = _json.loads(r"""
{
  "test_dict": {
    "test_key_1": "testing",
    "test_key_2": 123,
    "test_key_3": [
      "abc",
      456
    ]
  },
  "test_list": [
    13,
    13,
    "ltt",
    677,
    {
      "ok": true,
      "msg": "It works."
    }
  ]
}
""")

print(f"test_settings={test_settings!r}")
# Out:
# test_settings={'test_dict': {'test_key_1': 'testing', 'test_key_2': 123, 'test_key_3': ['abc', 456]}, 'test_list': [13, 13, 'ltt', 677, {'ok': True, 'msg': 'It works.'}]}

# %% [markdown]
# ### Test2: JSON Config

# %%
// to: request_payload
{
    "config": {
        "ok": true,
        "msg": "It works"
    },
    "list": [
        "some text",
        1234567
    ]
}

# %%
# Generated by Jupyter Config Cells. Edit the config cell above instead.
import json as _json

_config_source = r"""
{
    "config": {
        "ok": true,
        "msg": "It works"
    },
    "list": [
        "some text",
        1234567
    ]
}

""".strip("\n")

request_payload = _json.loads(r"""
{
  "config": {
    "ok": true,
    "msg": "It works"
  },
  "list": [
    "some text",
    1234567
  ]
}
""")

print(f"request_payload={request_payload!r}")
# Out:
# request_payload={'config': {'ok': True, 'msg': 'It works'}, 'list': ['some text', 1234567]}

# %%
request_payload
# Out:
# {'config': {'ok': True, 'msg': 'It works'}, 'list': ['some text', 1234567]}

# %% [markdown]
# ### Test3: Marked Config Cells

# %%
# to: model_settings
model:
  provider: deepseek
  name: deepseek-chat

# %%
# Generated by Jupyter Config Cells. Edit the config cell above instead.
import json as _json

_config_source = r"""
model:
  provider: deepseek
  name: deepseek-chat

""".strip("\n")

model_settings = _json.loads(r"""
{
  "model": {
    "provider": "deepseek",
    "name": "deepseek-chat"
  }
}
""")

print(f"model_settings={model_settings!r}")
# Out:
# model_settings={'model': {'provider': 'deepseek', 'name': 'deepseek-chat'}}
